# %%
import subprocess
import scipy as sp
import rasterio
import numpy as np
import meshio
import pandas as pd
from matplotlib import pyplot as plt

df = pd.read_csv('C:\\Users\\Andrea\\Documents\\Flow\\Optimization\\headData\\averageInTime\\wellHeadPo2016.csv')
wellLoc = df
wellLoc['Bottom'] = wellLoc['quota[m]']-wellLoc['depth']

def flowSimulation(P):
    #model parameters
    
    myfile = open(r"C:\Users\Andrea\Documents\Flow\OpenGeoSys\ogs62016\Po1.prj", "rt")
    contents = myfile.readlines()
    myfile.close()
    
    wordX = 'permeability'
    nameOfRivers = ['Adige','Secchia','DoraBaltea','Adda','Ticino','Chiese','Oglio','Tanaro','Po1','Po2','Po3','Po4','none']
    al = 0
    worda = 'alpha' + nameOfRivers[al]
    wordqm = 'qms'
    wordh0 = 'h0'
    j=0
    qms = 0
    h0 = 0
    P0 = h0*9810
    
    # set the K parameters 
    for i in range(len(contents)):
        if wordX in contents[i]:
            value = contents[i+2].split('<value>').pop().split('</value>')[0]
            if j>0:
                K = 10**P[j-1]
                value2= str(K)
                contents[i+2] = contents[i+2].replace(value, value2)
                permName = 'k%1d' % j 
                print(permName, value2)
            j += 1
            
    #set the alpha values
        if worda in contents[i]:
            if '<value>' in contents[i+2]:
                value = contents[i+2].split('<value>').pop().split('</value>')[0]
                a = P[6+al]
                value2= str(a)
                contents[i+2] = contents[i+2].replace(value, value2)
                print(worda, value2)
                al += 1
                worda = 'alpha' + nameOfRivers[al] 
               
    #set the alpha values          
        if wordqm in contents[i]:
              if '<value>' in contents[i+2]:
                    value = contents[i+2].split('<value>').pop().split('</value>')[0]
                    qmsValue2 = P[-1]*float(value)
                    value2= str(qmsValue2)
                    contents[i+2] = contents[i+2].replace(value, value2)                    
                    print('C_qms', qms+1 ,':', P[-1],';', 'qms', qms+1 , ':' , value2)
                    qms += 1
        if wordh0 in contents[i]:
              if '<value>' in contents[i+2]:
                    value = contents[i+2].split('<value>').pop().split('</value>')[0]
                    value2= str(P0)
                    contents[i+2] = contents[i+2].replace(value, value2)                    
                    print('C_qms', qms+1 ,':', P[-1],';', 'qms', qms+1 , ':' , value2)
                    qms += 1
    
            
    with open(r"C:\Users\Andrea\Documents\Flow\OpenGeoSys\ogs62016\Po2.prj", 'w') as file:
        file.writelines( contents )
    
    
    subprocess.check_call([r"C:\Users\Andrea\Documents\Flow\OpenGeoSys\ogs-6.4.3-16-g9a7564950-Windows-10.0.22000-python-3.10.7-utils\bin\ogs.exe", r"C:\Users\Andrea\Documents\Flow\OpenGeoSys\ogs62016\Po2.prj"])

    mesh = meshio.read(r"C:\Users\Andrea\Documents\Flow\OpenGeoSys\ogs62016\Po_ts_1_t_1.000000.vtu")
    data = mesh.points
    sample = np.array([wellLoc.longitude,wellLoc.latitude,wellLoc.Bottom]).T
    kdtree=sp.spatial.KDTree(data)
    dist,points=kdtree.query(sample,1)
    simulatedH = (mesh.point_data['pressure'][points].T)/9810+sample[:,2]
    fobj = (sum(((simulatedH-np.array(wellLoc['head[m]']))**2)**(1/2)))/len(wellLoc['head[m]'])
    print('RMSE: ',fobj)
    return fobj

# %%
P = [-1.087589124157963916e+01,    #log_10(k1)
     -8.885058263904584308e+00,    #log_10(k2)
     -1.231777616206400872e+01,    #log_10(k3)
     -1.028203150197779969e+01,    #log_10(k4)
     -1.105200435381599711e+01,    #log_10(k5)
     -1.442130128017940471e+01,    #log_10(k6)
     9.438946449848746448e-05,     #alphaAdige
     9.438946449848746448e-05,     #alphaSecchia
     9.438946449848746448e-05,     #alphaDoraBaltea
     9.438946449848746448e-05,     #alphaAdda
     9.438946449848746448e-05,     #alphaTicino
     9.438946449848746448e-05,     #alphaChiese
     9.438946449848746448e-05,     #alphaOglio
     9.438946449848746448e-05,     #alphaTanaro
     9.438946449848746448e-05,     #alphaPo1
     9.438946449848746448e-05,     #alphaPo2
     9.438946449848746448e-05,     #alphaPo3
     9.438946449848746448e-05,     #alphaPo4
     1,                            #C_qms1-29
    ]

# %%
#2run the model with the parameters set in P
flowSimulation(P)
# Out:
# k1 1.3307876394360073e-11
# k2 1.3029919604541498e-09
# k3 4.81087239761138e-13
# k4 5.2235829785151386e-11
# k5 8.871471183152974e-12
# k6 3.790519366015009e-15
# C_qms 1 : 1 ; qms 1 : 0
# alphaAdige 9.438946449848746e-05
# alphaSecchia 9.438946449848746e-05
# alphaDoraBaltea 9.438946449848746e-05
# alphaAdda 9.438946449848746e-05
# alphaTicino 9.438946449848746e-05
# alphaChiese 9.438946449848746e-05
# alphaOglio 9.438946449848746e-05
# alphaTanaro 9.438946449848746e-05
# alphaPo1 9.438946449848746e-05
# alphaPo2 9.438946449848746e-05
# alphaPo3 9.438946449848746e-05
# alphaPo4 9.438946449848746e-05
# C_qms 2 : 1 ; qms 2 : 1.5389643896159165e-06
# C_qms 3 : 1 ; qms 3 : 1.1956280666558574e-06
# C_qms 4 : 1 ; qms 4 : 1.4931960142744087e-06
# C_qms 5 : 1 ; qms 5 : 3.3987129699890504e-06
# C_qms 6 : 1 ; qms 6 : 4.609740216213087e-06
# C_qms 7 : 1 ; qms 7 : 1.2367215478877713e-06
# C_qms 8 : 1 ; qms 8 : 3.4469202117064544e-06
# C_qms 9 : 1 ; qms 9 : 1.0012691020890412e-06
# C_qms 10 : 1 ; qms 10 : 8.670303078360903e-07
# C_qms 11 : 1 ; qms 11 : 1.6367257435756275e-06
# C_qms 12 : 1 ; qms 12 : 1.8184405921798718e-07
# C_qms 13 : 1 ; qms 13 : 2.0323597871384837e-06
# C_qms 14 : 1 ; qms 14 : 2.8513805084773963e-07
# C_qms 15 : 1 ; qms 15 : 2.113937920955226e-06
# C_qms 16 : 1 ; qms 16 : 8.299819702209641e-07
# C_qms 17 : 1 ; qms 17 : 3.9537283673863067e-07
# C_qms 18 : 1 ; qms 18 : 2.8393658687643615e-07
# C_qms 19 : 1 ; qms 19 : 1.163468695842825e-07
# C_qms 20 : 1 ; qms 20 : 1.4895958508937941e-06
# C_qms 21 : 1 ; qms 21 : 7.339521887837751e-07
# C_qms 22 : 1 ; qms 22 : 8.502177497106797e-08
# C_qms 23 : 1 ; qms 23 : 1.8855640067362114e-07
# C_qms 24 : 1 ; qms 24 : 7.776892462275987e-07
# C_qms 25 : 1 ; qms 25 : 5.262358683032039e-07
# C_qms 26 : 1 ; qms 26 : 5.738027517973814e-07
# C_qms 27 : 1 ; qms 27 : 4.577536185252344e-08
# C_qms 28 : 1 ; qms 28 : 7.166174303869623e-07
# C_qms 29 : 1 ; qms 29 : 5.544105458123909e-07
# C_qms 30 : 1 ; qms 30 : 3.101469037189618e-07
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# Input In [3], in <cell line: 2>()
#       1 #2run the model with the parameters set in P
# ----> 2 flowSimulation(P)
#
# Input In [1], in flowSimulation(P)
#      72 with open(r"C:\Users\Andrea\Documents\Flow\OpenGeoSys\ogs62016\Po2.prj", 'w') as file:
#      73     file.writelines( contents )
# ---> 76 subprocess.check_call([r"C:\Users\Andrea\Documents\Flow\OpenGeoSys\ogs-6.4.3-16-g9a7564950-Windows-10.0.22000-python-3.10.7-utils\bin\ogs.exe", r"C:\Users\Andrea\Documents\Flow\OpenGeoSys\ogs62016\Po2.prj"])
#      78 mesh = meshio.read(r"C:\Users\Andrea\Documents\Flow\OpenGeoSys\ogs62016\Po_ts_1_t_1.000000.vtu")
#      79 data = mesh.points
#
# File ~\anaconda3\lib\subprocess.py:373, in check_call(*popenargs, **kwargs)
#     371     if cmd is None:
#     372         cmd = popenargs[0]
# --> 373     raise CalledProcessError(retcode, cmd)
#     374 return 0
#
# CalledProcessError: Command '['C:\\Users\\Andrea\\Documents\\Flow\\OpenGeoSys\\ogs-6.4.3-16-g9a7564950-Windows-10.0.22000-python-3.10.7-utils\\bin\\ogs.exe', 'C:\\Users\\Andrea\\Documents\\Flow\\OpenGeoSys\\ogs62016\\Po2.prj']' returned non-zero exit status 1.

# %%
#define hyperparameters
F=0.5
CR = 0.5
NP = 100
bounds = [(-7, -9),            #log_10(k1)
          (-8, -10),           #log_10(k2)
          (-8, -10),           #log_10(k3)
          (-9, -13),           #log_10(k4)
          (-9, -13),           #log_10(k5)
          (-11, -15),          #log_10(k6)
          (1e-4, 1e-8),        #alphaAdige
          (1e-4, 1e-8),        #alphaSecchia
          (1e-4, 1e-8),        #alphaDoraBaltea
          (1e-4, 1e-8),        #alphaAdda
          (1e-4, 1e-8),        #alphaTicino
          (1e-4, 1e-8),        #alphaChiese
          (1e-4, 1e-8),        #alphaOglio
          (1e-4, 1e-8),        #alphaTanaro
          (1e-4, 1e-8),        #alphaPo1
          (1e-4, 1e-8),        #alphaPo2
          (1e-4, 1e-8),        #alphaPo3
          (1e-4, 1e-8),        #alphaPo4
          (0, 1),              #C_qms1
          (0, 1),              #C_qms2
          (0, 1),              #C_qms3
          (0, 1),              #C_qms4
          (0, 1),              #C_qms5
          (0, 1),              #C_qms6
          (0, 1),              #C_qms7
          (0, 1),              #C_qms8
          (0, 1),              #C_qms9
          (0, 1),              #C_qms10
          (0, 1),              #C_qms11
          (0, 1),              #C_qms12
          (0, 1),              #C_qms13
          (0, 1),              #C_qms14
          (0, 1),              #C_qms15
          (0, 1),              #C_qms16
          (0, 1),              #C_qms17
          (0, 1),              #C_qms18
          (0, 1),              #C_qms19
          (0, 1),              #C_qms20
          (0, 1),              #C_qms21
          (0, 1),              #C_qms22
          (0, 1),              #C_qms23
          (0, 1),              #C_qms24
          (0, 1),              #C_qms25
          (0, 1),              #C_qms26
          (0, 1),              #C_qms27
          (0, 1),              #C_qms28
          (0, 1),              #C_qms29
           ]
maxIter = 100
tollerance = 1e-4

# %%
result = sp.optimize.differential_evolution(
    flowSimulation,
    bounds=bounds,
    maxiter=maxIter,
    popsize=NP,
    tol=tollerance, 
    mutation=F,
    disp=True,
    recombination = CR,
    polish=False,
    #updating='immediate',
    #workers=1
)
print(result)

# %%
#plot the error  in a map
mesh = meshio.read(r"C:\Users\Andrea\Documents\Flow\OpenGeoSys\ogs62016\Po_ts_1_t_1.000000.vtu")
data = mesh.points
sample = np.array([wellLoc.longitude,wellLoc.latitude,wellLoc.Bottom]).T
kdtree=sp.spatial.KDTree(data)
dist,points=kdtree.query(sample,1)
simulatedH = (mesh.point_data['pressure'][points].T)/9810+sample[:,2]

fobj = (sum(((simulatedH-np.array(wellLoc['head[m]']))**2)**(1/2)))/len(wellLoc['head[m]'])
print('fobj:',fobj)
err = simulatedH-np.array(wellLoc['head[m]'])
img = plt.imread(r"C:\Users\Andrea\Documents\Flow\Optimization\background.tif")
img = np.array(img)
img[:,:,3] = img[:,:,3]*0.32
ext = [540000.0000, 1100000.0000,5400000.0000,5740000.0000]
plt.imshow(img, zorder=0, extent=ext)
plt.scatter(sample[:,0],sample[:,1],zorder=1, s=10, c=err, cmap='gist_rainbow', vmin=-200, vmax=55)#vmin=min(err), vmax=max(err))
plt.colorbar()
plt.title('simulated-measure')
plt.show()
# Out:
# fobj: 19.075481851785934

# %%
for el in err:
    if type(el)!=np.float64:
        print(type(el))

# %%
counts, bins = np.histogram(err,bins=100)
plt.stairs(counts, bins,fill=True)
plt.xlabel('err = f_simulated-f_measured')
plt.axvline(x = np.average(err), color = 'g', label = 'Average error')
plt.axvline(x = np.average(err) + np.std(err), color = 'r', label = 'Avg + std')
plt.axvline(x = np.average(err) - np.std(err), color = 'r', label = 'Avg - std')
plt.legend()
print('Average error:', np.average(err))
print('error standard deviation:', np.std(err))
# Out:
# Average error: 6.125168080121383
# error standard deviation: 24.75102948825789

# %%
np.average(err)
